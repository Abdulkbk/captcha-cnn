# %%
import os

# %%
img_folder = '../images/'

# %%
os.walk(img_folder)
# Out:
# <generator object _walk at 0x000002325198F430>

# %%
for _, _, files in os.walk(img_folder):
    for f in files:
        print(f.split('.')[0])
# Out:
# 226md
# 22d5n
# 2356g
# 23mdg
# 23n88
# 243mm
# 244e2
# 245y5
# 24f6w
# 24pew
# 25257
# 253dc
# 25egp
# 25m6p
# 25p2m
# 25w53
# 264m5
# 268g2
# 28348
# 28x47
# 2b827
# 2bg48
# 2cegf
# 2cg58
# 2cgyx
# 2en7g
# 2enf4
# 2fxgd
# 2g783
# 2g7nm
# 2gyb6
# 2mg87
# 2mpnn
# 2n73f
# 2nbc5
# 2nbcx
# 2nf26
# 2npg6
# 2nx38
# 2p2y8
# 2pfpn
# 2w4y7
# 2wc38
# 2wx73
# 2x7bm
# 2xc2n
# 2ycn8
# 2yggg
# 325fb
# 32cnn
# 32dnn
# 33b22
# 33f7m
# 33n73
# 33ng4
# 33p4e
# 34b84
# 34fxm
# 34pcn
# 368y5
# 36bc2
# 36nx4
# 36w25
# 373gb
# 377xx
# 378e5
# 37d52
# 37ep6
# 387g2
# 38n57
# 3b4we
# 3bd8f
# 3bfnd
# 3bnyf
# 3bx86
# 3c7de
# 3cpwb
# 3d7bd
# 3den6
# 3dgmf
# 3ebnn
# 3ebpw
# 3eny7
# 3fbxd
# 3g2w6
# 3mxdn
# 3n2b4
# 3n3cf
# 3n7mx
# 3ndxd
# 3nfdn
# 3nnpw
# 3nw7w
# 3ny45
# 3p4nn
# 3p67n
# 3pe4g
# 3w2bw
# 3wnd3
# 3x325
# 3x5fm
# 3xcgg
# 3xng6
# 3ye2e
# 3ygde
# 3ym7f
# 428b6
# 42dw4
# 42nxy
# 42xpy
# 43gey
# 43mn5
# 43p5d
# 43xfe
# 4433m
# 445cc
# 44c22
# 44fyb
# 44xe8
# 44ype
# 467d5
# 46mbm
# 4743p
# 474ff
# 478nx
# ...
